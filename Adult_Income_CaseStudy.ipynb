# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Quantitative and Quantitative Analysis](#quan)**
# 2. **[Categorical and Quantitative Analysis](#catquan)**
# 3. **[Categorical and Categorical Analysis](#cat)**

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Load the adult dataset and check the first five observations

# %%
# type your code here
df=pd.read_csv('adult.csv')

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="quan"> </a>
# ## 1. Quantitative and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Is there any effect of a person's age on the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.scatterplot(x=df['age'],y=df['hours.per.week'])
plt.show()

# %% [raw]
# Non interpretable graph as data is highly scattered. No relationship between them.
# Can also use heatmap to validate the correlation.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Analyze the trend of the capital gain amount for different educational qualifications</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
#This can be done in three ways and all show same plot. Trend so we use Line graph

# %%
df.groupby(['education.num']).mean()['capital.gain'].plot()

# %%
sns.lineplot(x='education.num',y='capital.gain',data=df)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Check the effect of working hours of individuals on capital gain </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.head(1)
# Out:
#    age workclass  fnlwgt education  education.num marital.status occupation  \
# 0   90         ?   77053   HS-grad              9        Widowed          ?
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 0  Not-in-family  White  Female             0          4356              40
#
#   native.country income
# 0  United-States  <=50K

# %%
# type your code here

sns.scatterplot(x=df['hours.per.week'],y=df['capital.gain'])
plt.show()

# %% [raw]
# No effect on it at all. they arent correlated in anyways

# %%
#We can check using values and come up with conclusion also for this question
df[['hours.per.week', 'capital.gain']].corr()
# Out:
#                 hours.per.week  capital.gain
# hours.per.week        1.000000      0.078409
# capital.gain          0.078409      1.000000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4.  Find the trend in the average working hours corresponding to the age of an individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
#Correct method
df.groupby(['age']).mean()['hours.per.week'].plot()
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Check the distribution of the average capital loss corresponding to the age</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
#Correct method 
df.groupby(['age']).mean()['capital.loss'].plot()
plt.show()

# %%
df.groupby(['age'])['capital.loss'].mean().plot()
plt.show()   

#both are same as above. Because it filters the age and gives average from which capital loss is filtered
#Here column is filtered and taken mean and plotted

# %% [raw]
# Distribution is kde or histogram but practically impossible as they are univariate but this question is bivariate so we use line for this question

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there a negative relation between capital gain and age?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df.corr()

#Scatter or Heatmap
# Out:
#                      age    fnlwgt  education.num  capital.gain  capital.loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education.num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital.gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital.loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours.per.week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours.per.week
# age                   0.068756
# fnlwgt               -0.018768
# education.num         0.148123
# capital.gain          0.078409
# capital.loss          0.054256
# hours.per.week        1.000000

# %%
sns.scatterplot(x=df['age'],y=df['capital.gain'])
plt.show()

#No corelation as data is so dense and scattered. So not possible to deduce a if there is a negative correlation.
#So in this case we can also refer a heatmap for extra verification.

# %% [markdown]
# <a id="catquan"> </a>
# ## 2. Categorical and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Compare the average age with levels of income </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.head(1)
# Out:
#    age workclass  fnlwgt education  education.num marital.status occupation  \
# 0   90         ?   77053   HS-grad              9        Widowed          ?
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 0  Not-in-family  White  Female             0          4356              40
#
#   native.country income
# 0  United-States  <=50K

# %%
df.groupby('income').mean()
# Out:
#               age        fnlwgt  education.num  capital.gain  capital.loss  \
# income
# <=50K   36.783738  190340.86517       9.595065    148.752468     53.142921
# >50K    44.249841  188005.00000      11.611657   4006.142456    195.001530
#
#         hours.per.week
# income
# <=50K        38.840210
# >50K         45.473026

# %%
#correct one - correct 
df.groupby('income')['age'].mean().plot(kind='bar')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Check the distribution of working hours with respect to the gender of the individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [raw]
# Available - Box,violin,Bar,Strip,Swarm
#
# Violin is correct method as rest of them dont show the distribution. Box can also be used but only if we need ouliers

# %%
# type your code here
plt.figure(figsize=(15,8))
sns.violinplot(x=df['hours.per.week'],y=df['sex'])
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Compare the income of individuals based on their education</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.head(1)
# Out:
#    age workclass  fnlwgt education  education.num marital.status occupation  \
# 0   90         ?   77053   HS-grad              9        Widowed          ?
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 0  Not-in-family  White  Female             0          4356              40
#
#   native.country income
# 0  United-States  <=50K

# %%
# type your code here

#this actual categorical-categorical kinda question

# %%
df_cc=pd.crosstab(df['education'],df['income'])
df_cc.plot(kind='bar',figsize=(15,8))
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# As discussed In Class - Take education.num and income.
# Swarm or Strip or Box can be used

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='education.num',y='income',data=df)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the average age of males and females</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.groupby('sex')['age'].mean().plot(kind='bar')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Compare the distribution of working hours for the distinct classes of income
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(15,8))
sns.violinplot(y=df['income'],x=df['hours.per.week'])
plt.show()

# %%
#can also use Box if we want
plt.figure(figsize=(15,8))
sns.boxplot(y=df['income'],x=df['hours.per.week'])
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Identify the positively skewed distributions of age based on the gender and race of the individual
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
#Violin or Box can be used

plt.figure(figsize=(15,5))
sns.boxplot(x='race',y='age',data=df,hue='sex')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.violinplot(x='race',y='age',data=df,hue='sex')
plt.show()

# %% [raw]
# POSITIVE SKEW IS OBSERVED IN THE FOLLOWING:
# 1.for white race -in both male and female P1=P2(AS IN THE SIZE OF THE BOX) and W2>W1,hence postive skew
#
# 2.for amer-indian-eskimo P1=P2 AND W2>W1

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Compare the working hours for each working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df.head(1)
# Out:
#    age workclass  fnlwgt education  education.num marital.status occupation  \
# 0   90         ?   77053   HS-grad              9        Widowed          ?
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 0  Not-in-family  White  Female             0          4356              40
#
#   native.country income
# 0  United-States  <=50K

# %%
df.groupby('workclass')['hours.per.week'].mean().plot(kind='bar')
plt.show()

# %%
#Box can also be done. Will give much more insights
plt.figure(figsize=(15,8))
sns.boxplot(x='workclass',y='hours.per.week',data=df)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Compare the weightage based on demographic characteristics by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='sex',y='fnlwgt',data=df)
plt.show()

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Categorical and Categorical Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Study the variation in income by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df.head(1)
# Out:
#    age workclass  fnlwgt education  education.num marital.status occupation  \
# 0   90         ?   77053   HS-grad              9        Widowed          ?
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 0  Not-in-family  White  Female             0          4356              40
#
#   native.country income
# 0  United-States  <=50K

# %%
data1=pd.crosstab(df['income'],df['sex'])
data1.plot(kind='bar',stacked=True)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Compare the income by race</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.pivot_table(index='race',columns='income',values='age').plot(kind='bar',figsize=(15,8))

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Is there an all male profession according to the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df.groupby('occupation')['sex'].count().plot(kind='bar')

# %%
df.pivot_table(index='occupation',columns='sex',values='age',aggfunc='count')
# Out:
# sex                Female    Male
# occupation
# ?                   841.0  1002.0
# Adm-clerical       2537.0  1233.0
# Armed-Forces          NaN     9.0
# Craft-repair        222.0  3877.0
# Exec-managerial    1159.0  2907.0
# Farming-fishing      65.0   929.0
# Handlers-cleaners   164.0  1206.0
# Machine-op-inspct   550.0  1452.0
# Other-service      1800.0  1495.0
# Priv-house-serv     141.0     8.0
# Prof-specialty     1515.0  2625.0
# Protective-serv      76.0   573.0
# Sales              1263.0  2387.0
# Tech-support        348.0   580.0
# Transport-moving     90.0  1507.0

# %%
df.pivot_table(index='occupation',columns='sex',values='age',aggfunc='count').plot(kind='bar',stacked=True)

# %%
pd.crosstab(df['occupation'],df['sex'])
# Out:
# sex                Female  Male
# occupation
# ?                     841  1002
# Adm-clerical         2537  1233
# Armed-Forces            0     9
# Craft-repair          222  3877
# Exec-managerial      1159  2907
# Farming-fishing        65   929
# Handlers-cleaners     164  1206
# Machine-op-inspct     550  1452
# Other-service        1800  1495
# Priv-house-serv       141     8
# Prof-specialty       1515  2625
# Protective-serv        76   573
# Sales                1263  2387
# Tech-support          348   580
# Transport-moving       90  1507

# %% [raw]
# In this case we can say Armed-Forces is the only All male professional in data set

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. How does income vary with working class?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.pivot_table(index='workclass',columns='income',values='age',aggfunc='count').plot(kind='bar',figsize=(15,8))
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='workclass',data=df,hue='income')
plt.show()
#gives little more insight into data but both does count anyways

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. How is income related to marital status?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.pivot_table(index='marital.status',columns='income',values='age',aggfunc='count').plot(kind='bar',figsize=(15,8))
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Compare the income for different occupations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

df.groupby('occupation')['income'].count()
# Out:
# occupation
# ?                    1843
# Adm-clerical         3770
# Armed-Forces            9
# Craft-repair         4099
# Exec-managerial      4066
# Farming-fishing       994
# Handlers-cleaners    1370
# Machine-op-inspct    2002
# Other-service        3295
# Priv-house-serv       149
# Prof-specialty       4140
# Protective-serv       649
# Sales                3650
# Tech-support          928
# Transport-moving     1597
# Name: income, dtype: int64

# %%
data4=pd.crosstab(df['occupation'],df['income'])
data4.plot(kind='bar',figsize=(15,5))
plt.show()
