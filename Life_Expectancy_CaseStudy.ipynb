# %% [markdown]
# ### About the dataset (Life Expectancy Data)
#
# The dataset contains the health data of 2938 individuals useful for predicting the life expentency of the individuals. The features are related to economical factors, immunity realted factors, social factors and so on.
#
# Attribute Information:
#
# **Country:** Country of the recorded data
#
# **Year:** Year of the recorded data
#
# **Status:** Status of the country
#
# **Life expectancy:** Life expectancy in age (target/dependent variable)
#
# **Adult mortality:** Rate of adult mortality
#
# **Infant deaths:** Number of Infant Deaths per 1000 population
#
# **Alcohol:** Alcohol consumption (in litres of pure alcohol)
#
# **Percentage expenditure:** Expenditure on health as a percentage of GDP
#
# **Hepatitis B:** Hepatitis B immunization coverage among 1-year-olds (%)
#
# **Measles:** Number of reported cases per 1000 population
#
# **BMI:** Average BMI of entire population
#
# **Under-five deaths:** Number of under-five deaths per 1000 population
#
# **Polio:** Polio immunization coverage among 1-year-olds (%)
#
# **Total expenditure:** Government expenditure on health as a percentage of total government expenditure (%)
#
# **Diphtheria:** DTP3 immunization coverage among 1-year-olds (%)
#
# **HIV/AIDS:** Deaths per 1000 live births HIV/AIDS (0-4 years)
#
# **GDP:** Gross Domestic Product per capita (in USD)
#
# **Population:** Population of the country
#
# **Thinness 1-19 years:** Prevalence of thinness for age 1 to 19 (%)
#
# **Thinness 5-9 years:** Prevalence of thinness for age 5 to 9 (%)
#
# **Income composition of resources:** Human Development Index in terms of income composition of resources
#
# **Schooling:** Number of years of Schooling

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Load the life expectancy dataset and print the first five observations

# %%
# type your code here
df=pd.read_csv('Life_Expectancy_Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210    33736494
# 1   58.0               8.18        62.0       0.1  612.696514      327582
# 2   62.0               8.13        64.0       0.1  631.744976    31731688
# 3   67.0               8.52        67.0       0.1  669.959000     3696958
# 4   68.0               7.87        68.0       0.1   63.537231     2978599
#
#    Thinness  1-19 years Thinness 5-9 years  Income composition of resources  \
# 0                  17.2               17.3                            0.479
# 1                  17.5               17.5                            0.476
# 2                  17.7               17.7                            0.470
# 3                  17.9               18.0                            0.463
# 4                  18.2               18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Check the data type of each variable and if any variable is wrongly identified, do the needful</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2922 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult mortality                  2928 non-null   float64
#  5   Infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   Percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  Under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15  HIV/AIDS                         2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2938 non-null   object
#  18  Thinness  1-19 years             2904 non-null   float64
#  19  Thinness 5-9 years               2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(15), int64(4), object(3)
# memory usage: 505.1+ KB

# %%
#ValueError: could not convert string to float: '#'
df['Population']=df['Population'].str.replace('#','')

# %%
df['Population']=pd.to_numeric(df['Population'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2922 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult mortality                  2928 non-null   float64
#  5   Infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   Percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  Under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15  HIV/AIDS                         2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18  Thinness  1-19 years             2904 non-null   float64
#  19  Thinness 5-9 years               2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Create a DataFrame containing the count and percentage of missing entries in each variable</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
ser1=df.isna().sum()
ser1
# Out:
# Country                              0
# Year                                 0
# Status                              16
# Life expectancy                     10
# Adult mortality                     10
# Infant deaths                        0
# Alcohol                            194
# Percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# Under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# Thinness  1-19 years                34
# Thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
ser2=(df.isna().sum() / df.count() ) *100
ser2
# Out:
# Country                             0.000000
# Year                                0.000000
# Status                              0.547570
# Life expectancy                     0.341530
# Adult mortality                     0.341530
# Infant deaths                       0.000000
# Alcohol                             7.069971
# Percentage expenditure              0.000000
# Hepatitis B                        23.186583
# Measles                             0.000000
# BMI                                 1.170799
# Under-five deaths                   0.000000
# Polio                               0.650908
# Total expenditure                   8.333333
# Diphtheria                          0.650908
# HIV/AIDS                            0.000000
# GDP                                17.991968
# Population                         28.521435
# Thinness  1-19 years                1.170799
# Thinness 5-9 years                  1.170799
# Income composition of resources     6.026705
# Schooling                           5.873874
# dtype: float64

# %%
df_nan=pd.DataFrame({'NaN count':ser1,'Nan Percent':ser2})

# %%
df_nan
# Out:
#                                  NaN count  Nan Percent
# Country                                  0     0.000000
# Year                                     0     0.000000
# Status                                  16     0.547570
# Life expectancy                         10     0.341530
# Adult mortality                         10     0.341530
# Infant deaths                            0     0.000000
# Alcohol                                194     7.069971
# Percentage expenditure                   0     0.000000
# Hepatitis B                            553    23.186583
# Measles                                  0     0.000000
# BMI                                     34     1.170799
# Under-five deaths                        0     0.000000
# Polio                                   19     0.650908
# Total expenditure                      226     8.333333
# Diphtheria                              19     0.650908
# HIV/AIDS                                 0     0.000000
# GDP                                    448    17.991968
# Population                             652    28.521435
# Thinness  1-19 years                    34     1.170799
# Thinness 5-9 years                      34     1.170799
# Income composition of resources        167     6.026705
# Schooling                              163     5.873874

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3a. Are there any extreme values present in the government's total expenditure on health?
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df['Total expenditure'].plot(kind='box')

# %%
#The outliers are the extreme values in the dataset

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3b. Remove the outliers present in 'Total expenditure' using the quartiles of the variable
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
Q1=df['Total expenditure'].quantile(0.25)
Q3=df['Total expenditure'].quantile(0.75)
IQR=Q3-Q1
ul=Q3+(1.5*IQR)
ll=Q1-(1.5*IQR)

# %%
df[df['Total expenditure']>ul]
#32 outliers
# Out:
#                                Country  Year      Status  Life expectancy  \
# 1386                          Kiribati  2007  Developing             65.0
# 1496                           Liberia  2009  Developing             59.2
# 1573                            Malawi  2012  Developing             55.3
# 1603                          Maldives  2014  Developing             78.2
# 1650                  Marshall Islands  2013  Developing              NaN
# 1700  Micronesia (Federated States of)  2014  Developing             69.4
# 1701  Micronesia (Federated States of)  2013  Developing             69.2
# 1702  Micronesia (Federated States of)  2012  Developing             69.0
# 1703  Micronesia (Federated States of)  2011  Developing             68.9
# 1704  Micronesia (Federated States of)  2010  Developing             68.7
# 1705  Micronesia (Federated States of)  2009  Developing             68.5
# 1706  Micronesia (Federated States of)  2008  Developing             68.4
# 2108               Republic of Moldova  2010  Developing             68.8
# 2109               Republic of Moldova  2009  Developing             69.0
# 2303                      Sierra Leone  2009  Developing             47.1
# 2312                      Sierra Leone  2000  Developing             39.0
# 2713                            Tuvalu  2013  Developing              NaN
# 2795          United States of America  2014   Developed             79.1
# 2796          United States of America  2013   Developed             78.9
# 2797          United States of America  2012   Developed             78.8
# 2798          United States of America  2011   Developed             78.7
# 2799          United States of America  2010   Developed             78.7
# 2800          United States of America  2009   Developed             78.5
# 2801          United States of America  2008   Developed             78.2
# 2802          United States of America  2007   Developed             78.1
# 2803          United States of America  2006   Developed             77.8
# 2804          United States of America  2005   Developed             77.5
# 2805          United States of America  2004   Developed             77.5
# 2806          United States of America  2003   Developed             77.2
# 2807          United States of America  2002   Developed             77.0
# 2808          United States of America  2001   Developed             76.9
# 2809          United States of America  2000   Developed             76.8
#
#       Adult mortality  Infant deaths  Alcohol  Percentage expenditure  \
# 1386            211.0              0     0.68              188.710877
# 1496            277.0             10     3.75                5.592170
# 1573             42.0             31     0.01               82.768659
# 1603             62.0              0     0.01             2051.748615
# 1650              NaN              0     0.01              871.878317
# 1700            164.0              0     1.58                0.000000
# 1701            166.0              0     1.67                0.000000
# 1702            168.0              0     2.98                0.000000
# 1703            169.0              0     1.89                0.000000
# 1704            171.0              0     1.76                0.000000
# 1705            172.0              0     2.06                0.000000
# 1706            174.0              0     1.97                0.000000
# 2108            219.0              1     8.25                0.000000
# 2109            218.0              1     8.45                0.000000
# 2303            433.0             28     3.97               49.837127
# 2312            533.0             29     3.97               20.395683
# 2713              NaN              0     0.01               78.281203
# 2795             14.0             23     8.82                0.000000
# 2796             16.0             23     8.82                0.000000
# 2797             16.0             24     8.82                0.000000
# 2798             16.0             25     8.67                0.000000
# 2799             15.0             25     8.55                0.000000
# 2800             18.0             26     8.71                0.000000
# 2801             18.0             27     8.74                0.000000
# 2802             11.0             27     8.74                0.000000
# 2803            113.0             28     8.63                0.000000
# 2804            112.0             28     8.52                0.000000
# 2805            111.0             28     8.48                0.000000
# 2806            114.0             28     8.40                0.000000
# 2807            115.0             28     8.33                0.000000
# 2808            115.0             28     8.25                0.000000
# 2809            114.0             28     8.21                0.000000
#
#       Hepatitis B  Measles  ...  Polio  Total expenditure  Diphtheria  \
# 1386         96.0        0  ...   93.0              13.66        94.0
# 1496         64.0        6  ...   84.0              14.39        81.0
# 1573         96.0       11  ...   95.0              12.60        96.0
# 1603         99.0        0  ...   99.0              13.73        99.0
# 1650          8.0        0  ...   79.0              17.24        79.0
# 1700         81.0      140  ...   76.0              13.71        77.0
# 1701         83.0        0  ...   81.0              13.38        81.0
# 1702         82.0        0  ...   81.0              12.77        81.0
# 1703         83.0        0  ...   83.0              13.76        84.0
# 1704         88.0        0  ...   85.0              13.83        85.0
# 1705         89.0        0  ...   81.0              13.44        91.0
# 1706         89.0        0  ...   88.0              12.94        85.0
# 2108         98.0        0  ...   97.0              12.80         9.0
# 2109         89.0        0  ...   87.0              12.49        85.0
# 2303         84.0       31  ...   81.0              13.13        84.0
# 2312          NaN     3575  ...   46.0              13.63        44.0
# 2713          9.0        0  ...    9.0              16.61         9.0
# 2795         92.0      667  ...   93.0              17.14        95.0
# 2796         91.0      187  ...   93.0              16.90        94.0
# 2797          9.0       55  ...   93.0              17.20        94.0
# 2798         91.0      220  ...   94.0              17.60        96.0
# 2799         92.0       63  ...   93.0              17.20        95.0
# 2800         92.0       71  ...   93.0              17.00        95.0
# 2801         94.0      140  ...   94.0              16.20        96.0
# 2802         93.0       43  ...   93.0              15.57        96.0
# 2803         93.0       55  ...   93.0              15.27        96.0
# 2804         93.0       66  ...   92.0              15.15        96.0
# 2805         92.0       37  ...   92.0              15.14        96.0
# 2806         92.0       56  ...   91.0              15.60        96.0
# 2807         88.0       41  ...    9.0              14.55        94.0
# 2808         89.0      116  ...   89.0              13.73        94.0
# 2809          9.0       85  ...    9.0              13.70        94.0
#
#       HIV/AIDS          GDP  Population  Thinness  1-19 years  \
# 1386       0.1  1357.632211     96311.0                   0.2
# 1496       2.1    33.667491   3811528.0                   7.6
# 1573       8.3   374.518820    169735.0                   6.6
# 1603       0.1  7716.241500        41.0                  13.6
# 1650       0.1  3617.752354         NaN                   0.1
# 1700       0.1          NaN         NaN                   0.2
# 1701       0.1          NaN         NaN                   0.2
# 1702       0.1          NaN         NaN                   0.2
# 1703       0.1          NaN         NaN                   0.2
# 1704       0.1          NaN         NaN                   0.2
# 1705       0.1          NaN         NaN                   0.2
# 1706       0.1          NaN         NaN                   0.2
# 2108       0.1          NaN         NaN                   2.8
# 2109       0.1          NaN         NaN                   2.9
# 2303       1.7   394.593244     63126.0                   8.5
# 2312       1.2   139.314773   4564297.0                   1.3
# 2713       0.1  3542.135890      1819.0                   0.2
# 2795       0.1          NaN         NaN                   0.8
# 2796       0.1          NaN         NaN                   0.7
# 2797       0.1          NaN         NaN                   0.7
# 2798       0.1          NaN         NaN                   0.7
# 2799       0.1          NaN         NaN                   0.7
# 2800       0.1          NaN         NaN                   0.7
# 2801       0.1          NaN         NaN                   0.7
# 2802       0.1          NaN         NaN                   0.7
# 2803       0.1          NaN         NaN                   0.7
# 2804       0.1          NaN         NaN                   0.7
# 2805       0.1          NaN         NaN                   0.7
# 2806       0.1          NaN         NaN                   0.7
# 2807       0.1          NaN         NaN                   0.8
# 2808       0.1          NaN         NaN                   0.8
# 2809       0.1          NaN         NaN                   0.8
#
#       Thinness 5-9 years  Income composition of resources  Schooling
# 1386                 0.1                            0.574       11.8
# 1496                 7.4                            0.400        9.7
# 1573                 6.5                            0.454       10.7
# 1603                13.7                            0.693       12.7
# 1650                 0.1                              NaN        0.0
# 1700                 0.2                            0.639       11.7
# 1701                 0.2                            0.641       11.7
# 1702                 0.2                            0.640       11.7
# 1703                 0.2                            0.638       11.7
# 1704                 0.2                            0.633       11.5
# 1705                 0.2                            0.629       11.4
# 1706                 0.2                            0.628       11.2
# 2108                 3.0                              NaN        NaN
# 2109                 3.1                              NaN        NaN
# 2303                 8.4                            0.375        8.5
# 2312                 1.4                            0.292        6.7
# 2713                 0.1                              NaN        0.0
# 2795                 0.6                              NaN        NaN
# 2796                 0.6                              NaN        NaN
# 2797                 0.6                              NaN        NaN
# 2798                 0.6                              NaN        NaN
# 2799                 0.6                              NaN        NaN
# 2800                 0.6                              NaN        NaN
# 2801                 0.6                              NaN        NaN
# 2802                 0.6                              NaN        NaN
# 2803                 0.6                              NaN        NaN
# 2804                 0.6                              NaN        NaN
# 2805                 0.6                              NaN        NaN
# 2806                 0.6                              NaN        NaN
# 2807                 0.6                              NaN        NaN
# 2808                 0.6                              NaN        NaN
# 2809                 0.7                              NaN        NaN
#
# [32 rows x 22 columns]

# %%
df[df['Total expenditure']<ll]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Status, Life expectancy, Adult mortality, Infant deaths, Alcohol, Percentage expenditure, Hepatitis B, Measles, BMI, Under-five deaths, Polio, Total expenditure, Diphtheria, HIV/AIDS, GDP, Population, Thinness  1-19 years, Thinness 5-9 years, Income composition of resources, Schooling]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_noOutliers=df[(df['Total expenditure']<ul)|(df['Total expenditure']>ll)]

# %%
df_noOutliers
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 1     ...   58.0               8.18        62.0       0.1  612.696514
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 3     ...   67.0               8.52        67.0       0.1  669.959000
# 4     ...   68.0               7.87        68.0       0.1   63.537231
# ...   ...    ...                ...         ...       ...         ...
# 2933  ...   67.0               7.13        65.0      33.6  454.366654
# 2934  ...    7.0               6.52        68.0      36.7  453.351155
# 2935  ...   73.0               6.53        71.0      39.8   57.348340
# 2936  ...   76.0               6.16        75.0      42.1  548.587312
# 2937  ...   78.0               7.10        78.0      43.5  547.358879
#
#       Population  Thinness  1-19 years  Thinness 5-9 years  \
# 0     33736494.0                  17.2                17.3
# 1       327582.0                  17.5                17.5
# 2     31731688.0                  17.7                17.7
# 3      3696958.0                  17.9                18.0
# 4      2978599.0                  18.2                18.2
# ...          ...                   ...                 ...
# 2933  12777511.0                   9.4                 9.4
# 2934  12633897.0                   9.8                 9.9
# 2935    125525.0                   1.2                 1.3
# 2936  12366165.0                   1.6                 1.7
# 2937  12222251.0                  11.0                11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2712 rows x 22 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Split the data such that 'X' will contain all the indepentdent variables and 'y' will contain the target variable</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Hint:** 'Life expectancy' is the target variable depending on the remaining variables.

# %%
# type your code here

x=df.drop('Life expectancy',axis=1)
x
# Out:
#           Country  Year      Status  Adult mortality  Infant deaths  Alcohol  \
# 0     Afghanistan  2015  Developing            263.0             62     0.01
# 1     Afghanistan  2014  Developing            271.0             64     0.01
# 2     Afghanistan  2013  Developing            268.0             66     0.01
# 3     Afghanistan  2012  Developing            272.0             69     0.01
# 4     Afghanistan  2011  Developing            275.0             71     0.01
# ...           ...   ...         ...              ...            ...      ...
# 2933     Zimbabwe  2004  Developing            723.0             27     4.36
# 2934     Zimbabwe  2003  Developing            715.0             26     4.06
# 2935     Zimbabwe  2002  Developing             73.0             25     4.43
# 2936     Zimbabwe  2001  Developing            686.0             25     1.72
# 2937     Zimbabwe  2000  Developing            665.0             24     1.68
#
#       Percentage expenditure  Hepatitis B  Measles   BMI  ...  Polio  \
# 0                  71.279624         65.0     1154  19.1  ...    6.0
# 1                  73.523582         62.0      492  18.6  ...   58.0
# 2                  73.219243         64.0      430  18.1  ...   62.0
# 3                  78.184215         67.0     2787  17.6  ...   67.0
# 4                   7.097109         68.0     3013  17.2  ...   68.0
# ...                      ...          ...      ...   ...  ...    ...
# 2933                0.000000         68.0       31  27.1  ...   67.0
# 2934                0.000000          7.0      998  26.7  ...    7.0
# 2935                0.000000         73.0      304  26.3  ...   73.0
# 2936                0.000000         76.0      529  25.9  ...   76.0
# 2937                0.000000         79.0     1483  25.5  ...   78.0
#
#       Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0                  8.16        65.0       0.1  584.259210  33736494.0
# 1                  8.18        62.0       0.1  612.696514    327582.0
# 2                  8.13        64.0       0.1  631.744976  31731688.0
# 3                  8.52        67.0       0.1  669.959000   3696958.0
# 4                  7.87        68.0       0.1   63.537231   2978599.0
# ...                 ...         ...       ...         ...         ...
# 2933               7.13        65.0      33.6  454.366654  12777511.0
# 2934               6.52        68.0      36.7  453.351155  12633897.0
# 2935               6.53        71.0      39.8   57.348340    125525.0
# 2936               6.16        75.0      42.1  548.587312  12366165.0
# 2937               7.10        78.0      43.5  547.358879  12222251.0
#
#       Thinness  1-19 years  Thinness 5-9 years  \
# 0                     17.2                17.3
# 1                     17.5                17.5
# 2                     17.7                17.7
# 3                     17.9                18.0
# 4                     18.2                18.2
# ...                    ...                 ...
# 2933                   9.4                 9.4
# 2934                   9.8                 9.9
# 2935                   1.2                 1.3
# 2936                   1.6                 1.7
# 2937                  11.0                11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 21 columns]

# %%
x.shape
# Out:
# (2938, 21)

# %%
df.shape
# Out:
# (2938, 22)

# %%
y=df['Life expectancy']
y
# Out:
# 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
#         ...
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: Life expectancy, Length: 2938, dtype: float64

# %%
y.shape
# Out:
# (2938,)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Split the independent variables into two sets with the proportion of 70:30</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

from sklearn.model_selection import train_test_split

# %%
xtrain,ytrain=train_test_split(x,train_size=0.7)

# %%
xtrain.shape
# Out:
# (2056, 21)

# %%
ytrain.shape
# Out:
# (882, 21)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. How would you treat the missing values in the variable 'GDP'?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df['GDP']
# Out:
# 0       584.259210
# 1       612.696514
# 2       631.744976
# 3       669.959000
# 4        63.537231
#            ...
# 2933    454.366654
# 2934    453.351155
# 2935     57.348340
# 2936    548.587312
# 2937    547.358879
# Name: GDP, Length: 2938, dtype: float64

# %%
df['GDP'].isna().sum()
# Out:
# 448

# %%
df[df['GDP'].isna()]['Country'].unique()
# Out:
# array(['Bahamas', 'Bolivia (Plurinational State of)', "Côte d'Ivoire",
#        'Congo', 'Cook Islands', 'Czechia',
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Egypt', 'Eritrea', 'Gambia',
#        'Iran (Islamic Republic of)', 'Iraq', 'Kyrgyzstan',
#        "Lao People's Democratic Republic", 'Libya',
#        'Micronesia (Federated States of)', 'Monaco', 'Niue',
#        'Papua New Guinea', 'Republic of Korea', 'Republic of Moldova',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'San Marino',
#        'Sao Tome and Principe', 'Slovakia', 'Somalia', 'South Sudan',
#        'Syrian Arab Republic',
#        'The former Yugoslav republic of Macedonia',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United Republic of Tanzania', 'United States of America',
#        'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'Yemen'],
#       dtype=object)

# %%
df.drop(df[df['GDP'].isna()].index,inplace=True)

# %%
df
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 1     ...   58.0               8.18        62.0       0.1  612.696514
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 3     ...   67.0               8.52        67.0       0.1  669.959000
# 4     ...   68.0               7.87        68.0       0.1   63.537231
# ...   ...    ...                ...         ...       ...         ...
# 2933  ...   67.0               7.13        65.0      33.6  454.366654
# 2934  ...    7.0               6.52        68.0      36.7  453.351155
# 2935  ...   73.0               6.53        71.0      39.8   57.348340
# 2936  ...   76.0               6.16        75.0      42.1  548.587312
# 2937  ...   78.0               7.10        78.0      43.5  547.358879
#
#       Population  Thinness  1-19 years  Thinness 5-9 years  \
# 0     33736494.0                  17.2                17.3
# 1       327582.0                  17.5                17.5
# 2     31731688.0                  17.7                17.7
# 3      3696958.0                  17.9                18.0
# 4      2978599.0                  18.2                18.2
# ...          ...                   ...                 ...
# 2933  12777511.0                   9.4                 9.4
# 2934  12633897.0                   9.8                 9.9
# 2935    125525.0                   1.2                 1.3
# 2936  12366165.0                   1.6                 1.7
# 2937  12222251.0                  11.0                11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2490 rows x 22 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7.There are 16 observations for which the status of the corresponding country is unknown, impute this status with an appropriate values</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
#My observation use mode to fill na values

# %%
# type your code here

df['Status'].isna().sum()
# Out:
# 16

# %%
df['Status'].notnull().sum()
# Out:
# 2922

# %%
df[df['Status'].isna()]['Country']
# Out:
# 6               Afghanistan
# 15              Afghanistan
# 27                  Albania
# 46                  Algeria
# 65      Antigua and Barbuda
# 75      Antigua and Barbuda
# 82                Argentina
# 93                Argentina
# 104                 Armenia
# 118               Australia
# 136                 Austria
# 148              Azerbaijan
# 458              Cabo Verde
# 1129                  Haiti
# 2003               Paraguay
# 2068               Portugal
# Name: Country, dtype: object

# %%
df[df['Country']=='Haiti']['Status'].mode()[0]
# Out:
# 'Developing'

# %%
import scipy
from scipy import stats
from scipy.stats import mode

# %%
df['Status'].fillna(df.groupby(by='Country')['Status'].transform(lambda x:x.mode),inplace=True)

# %%
df['Status'].isna().sum()
# Out:
# 0

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Define a function to find the extreme values in alcohol consumption
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

df['Alcohol']
# Out:
# 0       0.01
# 1       0.01
# 2       0.01
# 3       0.01
# 4       0.01
#         ...
# 2933    4.36
# 2934    4.06
# 2935    4.43
# 2936    1.72
# 2937    1.68
# Name: Alcohol, Length: 2938, dtype: float64

# %%
df['Alcohol'].plot(kind='box')

# %%
q1=df['Alcohol'].quantile(0.25)
q2=df['Alcohol'].quantile(0.5)
q3=df['Alcohol'].quantile(0.75)

# %%
IQR=q3-q1
ul=q3+(1.5*IQR)
ll=q1-(1.5*IQR)

# %%
df[df['Alcohol']>ul]
# Out:
#      Country  Year      Status  Life expectancy  Adult mortality  \
# 874  Estonia  2007  Developing             73.0            189.0
#
#      Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 874              0    17.87              1904.12469         95.0        1
#
#      ...  Polio  Total expenditure  Diphtheria  HIV/AIDS        GDP  \
# 874  ...   95.0               5.16        95.0       0.1  16586.452
#
#      Population  Thinness  1-19 years  Thinness 5-9 years  \
# 874     13468.0                   2.0                 2.1
#
#      Income composition of resources  Schooling
# 874                            0.829       16.1
#
# [1 rows x 22 columns]

# %%
def Extreme_values(x):
    if (x>ul) or (x<ll):
        return True
    return False

# %%
df[df['Alcohol'].apply(Extreme_values)]
# Out:
#      Country  Year      Status  Life expectancy  Adult mortality  \
# 874  Estonia  2007  Developing             73.0            189.0
#
#      Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 874              0    17.87              1904.12469         95.0        1
#
#      ...  Polio  Total expenditure  Diphtheria  HIV/AIDS        GDP  \
# 874  ...   95.0               5.16        95.0       0.1  16586.452
#
#      Population  Thinness  1-19 years  Thinness 5-9 years  \
# 874     13468.0                   2.0                 2.1
#
#      Income composition of resources  Schooling
# 874                            0.829       16.1
#
# [1 rows x 22 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Create a column 'Life_expectancy_level' such that it will contain three levels (High, Medium, Low) based on the life expectancy </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df['Life expectancy Category']=pd.cut(df['Life expectancy'],3,labels=['Low','Medium','High'])
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0               8.16        65.0       0.1  584.259210    33736494
# 1               8.18        62.0       0.1  612.696514      327582
# 2               8.13        64.0       0.1  631.744976    31731688
# 3               8.52        67.0       0.1  669.959000     3696958
# 4               7.87        68.0       0.1   63.537231     2978599
#
#    Thinness  1-19 years  Thinness 5-9 years Income composition of resources  \
# 0                  17.2                17.3                           0.479
# 1                  17.5                17.5                           0.476
# 2                  17.7                17.7                           0.470
# 3                  17.9                18.0                           0.463
# 4                  18.2                18.2                           0.454
#
#    Schooling  Life expectancy Category
# 0       10.1                    Medium
# 1       10.0                    Medium
# 2        9.9                    Medium
# 3        9.8                    Medium
# 4        9.5                    Medium
#
# [5 rows x 23 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Check how life expectancy has changed over the years in China</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df['Life expectancy']

# %%
df[df['Country']=='China']
# Out:
#     Country  Year      Status  Life expectancy  Adult mortality  \
# 560   China  2015  Developing             76.1             85.0
# 561   China  2014  Developing             75.8             86.0
# 562   China  2013  Developing             75.6             88.0
# 563   China  2012  Developing             75.4             89.0
# 564   China  2011  Developing             75.2             91.0
# 565   China  2010  Developing             75.0             92.0
# 566   China  2009  Developing             74.9             93.0
# 567   China  2008  Developing             74.5             97.0
# 568   China  2007  Developing             74.4             96.0
# 569   China  2006  Developing             74.2             98.0
# 570   China  2005  Developing             73.9             99.0
# 571   China  2004  Developing             73.5             11.0
# 572   China  2003  Developing             73.1             13.0
# 573   China  2002  Developing             72.7             16.0
# 574   China  2001  Developing             72.2             11.0
# 575   China  2000  Developing             71.7            115.0
#
#      Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 560            157      NaN                0.000000         99.0    42361
# 561            171     5.78              109.874390         99.0    52628
# 562            185     5.79                9.955532         99.0    26883
# 563            201     5.74               94.434457         99.0     6183
# 564            215     5.63               91.267498         99.0     9943
# 565            231     5.75                5.660755         99.0    38159
# 566            248     4.88               50.283489         99.0    52461
# 567            266     4.27               39.225097         95.0   131441
# 568            285     3.88              312.662482         92.0   109023
# 569            307     3.28               29.743430         91.0    99602
# 570            332     2.92              171.659603         84.0   124219
# 571            360     3.04                1.586685         79.0    70549
# 572            391     2.96              122.936535         75.0    71879
# 573            422     2.91              106.359036          7.0    58341
# 574            457     2.84               14.230645         65.0    88962
# 575            490     3.06               17.460574          6.0    71093
#
#      ...  Polio  Total expenditure  Diphtheria  HIV/AIDS          GDP  \
# 560  ...   99.0                NaN        99.0       0.1   869.211938
# 561  ...   99.0               5.55        99.0       0.1  7683.523800
# 562  ...   99.0               5.39        99.0       0.1   777.775940
# 563  ...   99.0               5.26        99.0       0.1  6337.882993
# 564  ...   99.0               5.30        99.0       0.1  5633.796160
# 565  ...   99.0               4.89        99.0       0.1   456.512487
# 566  ...   99.0               5.80        99.0       0.1  3838.434292
# 567  ...   99.0               4.59        97.0       0.1  3471.247547
# 568  ...   94.0               4.32        93.0       0.1  2695.366223
# 569  ...   94.0               4.52        93.0       0.1   299.229676
# 570  ...   87.0               4.66        87.0       0.1  1753.417800
# 571  ...   87.0               4.72        87.0       0.1   158.668462
# 572  ...   87.0               4.82        86.0       0.1  1288.642924
# 573  ...   86.0               4.79        86.0       0.1  1148.585700
# 574  ...   86.0               4.56        86.0       0.1   153.182400
# 575  ...   86.0               4.60        85.0       0.1   959.372181
#
#      Population  Thinness  1-19 years Thinness 5-9 years  \
# 560      137122                   3.6                2.9
# 561      136427                   3.7                3.0
# 562      135738                   3.8                3.2
# 563      135695                   3.9                3.3
# 564      134413                   4.1                3.5
# 565      133775                   4.2                3.6
# 566      133126                   4.4                3.8
# 567     1324655                   4.5                4.0
# 568     1317885                   4.7                4.1
# 569       13112                   4.8                4.3
# 570       13372                   5.0                4.4
# 571      129675                   5.1                4.6
# 572       12884                   5.3                4.7
# 573        1284                   5.5                4.9
# 574      127185                   5.7                5.0
# 575     1262645                   5.9                5.1
#
#      Income composition of resources  Schooling
# 560                            0.734       13.5
# 561                            0.723       13.1
# 562                            0.713       12.7
# 563                            0.703       12.4
# 564                            0.700       12.8
# 565                            0.691       12.5
# 566                            0.682       12.2
# 567                            0.672       11.9
# 568                            0.659       11.4
# 569                            0.646       11.0
# 570                            0.634       10.6
# 571                            0.622       10.2
# 572                            0.610        9.9
# 573                            0.600        9.7
# 574                            0.592        9.6
# 575                            0.583        9.5
#
# [16 rows x 22 columns]

# %%
cval=df[df['Country']=='China'][['Year','Life expectancy']]

# %%
cval
# Out:
#      Year  Life expectancy
# 560  2015             76.1
# 561  2014             75.8
# 562  2013             75.6
# 563  2012             75.4
# 564  2011             75.2
# 565  2010             75.0
# 566  2009             74.9
# 567  2008             74.5
# 568  2007             74.4
# 569  2006             74.2
# 570  2005             73.9
# 571  2004             73.5
# 572  2003             73.1
# 573  2002             72.7
# 574  2001             72.2
# 575  2000             71.7

# %%
sns.scatterplot(x='Year',y='Life expectancy',data=cval)
plt.show()

# %%
#postiviely correlated
#As the Year increases Life expeteancy also increases.
